# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" width="10%" height="15%">
# # Capstone Project: Suspicious Object Detection
# Welcome to my Capstone Project. This code must be run on Google Colab in order to work.
#
# Note: In the Data Import, Cleaning & Annotation section, are all done on Roboflow (web base tool)

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Problem Statement](#Problem-Statement)
# - [Data import,cleaning and annotation](#Data-import,-cleaning-and-annotation)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Feature Selection](#Feature-Selection)
# - [Modelling](#Modelling)
# - [Model Evaluation](#Model-Evaluation)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ---
# # Background
#
#
#
# ---

# %% [markdown]
# Singapore's urban landscape is characterized by its high-density environment, necessitating the development and maintenance of robust public transportation systems, particularly the Mass Rapid Transit (MRT) system. Serving millions of residents and visitors each day, the MRT system is the lifeblood of Singapore's transit infrastructure. However, the same density and dependence make it susceptible to various safety and security concerns, including the potential for crime, loss of personal items, and issues related to cleanliness.
#
# The current security measures in place largely involve traditional video-based surveillance in train cabins and other public spaces. While these systems have served as a deterrent and means of post-incident investigation, their efficiency is limited when it comes to real-time detection and tracking of suspicious objects. Manual monitoring of surveillance footage is labor-intensive and prone to human errors, such as oversight or misinterpretation. Moreover, the existing systems are inadequate in providing real-time alerts, which are critical in situations requiring immediate attention.
#
# Beyond security, Singapore, with its reputation for cleanliness and order, also faces challenges related to waste management and lost items in public spaces. An effective object detection system could assist in these areas, contributing to the city's overall cleanliness and helping in the retrieval of lost items.
#
# The limitations of the existing surveillance methods highlight a crucial gap in Singapore's safety and security measures, particularly in the MRT system. They underscore the need for a more advanced, intelligent, and autonomous system capable of detecting, classifying, and tracking objects, particularly those that are suspicious, in real-time. This new system should not only enhance accuracy and reliability but also address privacy concerns that come with increased surveillance. The development and implementation of such a system can significantly contribute to the enhancement of security, overall safety, and orderliness in Singapore's public spaces.

# %% [markdown]
# ---
# # Problem Statement
# ---

# %% [markdown]
# In the densely populated city-state of Singapore, where the Mass Rapid Transit (MRT) system is a primary mode of transportation, the critical importance of public safety and security cannot be overstated. The current surveillance methods, primarily conventional video-based monitoring in train cabins and other public spaces, have proved to be less efficient in real-time object detection and tracking, especially for suspicious objects that could pose significant risks and security threats.
#
# This limitation is particularly concerning in high-density spaces like train cabins, where quick identification and resolution of such threats are crucial. Moreover, given Singapore's emphasis on public cleanliness and order, an effective object detection system can also contribute to better waste management and retrieval of lost items. The existing surveillance systems suffer from labor-intensive and error-prone manual monitoring, lack of real-time alerts, and absence of advanced features like object classification.
#
# Therefore, there is a pressing need for an intelligent, autonomous object detection surveillance system capable of detecting, classifying, and tracking objects, including suspicious ones, in real-time. The successful development and implementation of such a system, while ensuring high accuracy, reliability, and addressing privacy concerns, could significantly enhance the security and overall safety in Singapore's public spaces.

# %% [markdown]
# ---
# # Data Import and Cleaning
# ---

# %% [markdown]
# ---
# # Exploratory Data Analysis
#
#
#
# ---

# %% [markdown]
# ---
# # Feature Selection
#
#
#
# ---

# %% [markdown]
# ---
# # Modelling
#
#
#
# ---

# %% [markdown]
# ## Before you start
#
# Do ensure you are in the Google Colab environment.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8 and import the necessary files

# %% [markdown]
# Run the codes below to install YOLOv8

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ### Importing Data from Roboflow tool for annotation
#
# I can import these annotations in the most simplest way of simply using YOLOv8 directly in a Python environment.

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets


# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZNrtvlR5mk5kbSppqj5w")
project = rf.workspace("capstone-mbl6k").project("suspicious-objects-articles-3")
dataset = project.version(1).download("yolov8")
# Out:
# /content/datasets
# Collecting roboflow
#   Downloading roboflow-1.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 2.0 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.12.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.16)
# Collecting wget (from roboflow)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.41.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (4.8.0.74)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading Pillow-8.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 22.3 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=6de26048cfdc1a7852d93d4fca0e0626835b040d1de9429ab8bc12b72b01288e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, Pillow, idna, cycler, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# Successfully installed Pillow-8.4.0 certifi-2022.12.7 cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.2 supervision-0.12.0 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# Downloading Dataset Version Zip in suspicious-objects-articles-3-1 to yolov8: 100% [270382313 / 270382313] bytes
# Extracting Dataset Version Zip to suspicious-objects-articles-3-1 in yolov8:: 100%|██████████| 10256/10256 [00:02<00:00, 3469.13it/s]

# %% [markdown]
# ## Custom Training
#
# After importing, I will run the YOLOv8 Model on Google Colab for its extensive RAM at 25 epochs. Run the code as shown below

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100% 21.5M/21.5M [00:00<00:00, 49.1MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/suspicious-objects-articles-3-1/data.yaml, epochs=25, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 45.7MB/s]
# 2023-07-31 11:51:57.833281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.Detect                [3, [128, 256, 512]]
# Model summary: 225 layers, 11136761 parameters, 11136745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/suspicious-objects-articles-3-1/train/labels... 4703 images, 3 backgrounds, 0 corrupt: 100% 4703/4703 [00:03<00:00, 1457.42it/s]
# train: New cache created: /content/datasets/suspicious-objects-articles-3-1/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1472, len(boxes) = 5036. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/suspicious-objects-articles-3-1/valid/labels... 229 images, 0 backgrounds, 0 corrupt: 100% 229/229 [00:00<00:00, 1365.22it/s]
# val: New cache created: /content/datasets/suspicious-objects-articles-3-1/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 76, len(boxes) = 248. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      5.94G      1.436      2.189        1.8         27        800: 100% 294/294 [04:03<00:00,  1.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.30it/s]
#                    all        229        248      0.768      0.688      0.794       0.49
#         suspicious-cap        229         92      0.909      0.541      0.848      0.466
#       suspicious-masks        229         60      0.662      0.783      0.813      0.584
#  suspicious-sunglasses        229         96      0.734       0.74       0.72      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      7.19G      1.194      1.163      1.541         32        800: 100% 294/294 [03:55<00:00,  1.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:03<00:00,  2.01it/s]
#                    all        229        248      0.575      0.527      0.507      0.283
#         suspicious-cap        229         92      0.871      0.391      0.572      0.271
#       suspicious-masks        229         60      0.706        0.7      0.729      0.475
#  suspicious-sunglasses        229         96       0.15       0.49       0.22      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      7.19G      1.189      1.156      1.543         30        800: 100% 294/294 [03:53<00:00,  1.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.46it/s]
#                    all        229        248      0.752      0.691      0.706      0.386
#         suspicious-cap        229         92      0.757      0.777        0.8      0.399
#       suspicious-masks        229         60        0.9      0.598      0.656      0.448
#  suspicious-sunglasses        229         96        0.6      0.698      0.661      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25       7.2G      1.226      1.171      1.575         39        800: 100% 294/294 [03:55<00:00,  1.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.94it/s]
#                    all        229        248      0.651      0.569       0.62      0.323
#         suspicious-cap        229         92      0.707      0.473      0.626      0.291
#       suspicious-masks        229         60      0.636      0.567      0.616      0.386
#  suspicious-sunglasses        229         96       0.61      0.667      0.617      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25       7.2G      1.181      1.102      1.538         34        800: 100% 294/294 [03:55<00:00,  1.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.96it/s]
#                    all        229        248      0.813      0.756      0.798       0.44
#         suspicious-cap        229         92      0.834      0.762      0.842      0.318
#       suspicious-masks        229         60      0.849      0.733      0.804      0.551
#  suspicious-sunglasses        229         96      0.756      0.774      0.749      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25       7.2G      1.141      1.022      1.506         35        800: 100% 294/294 [03:54<00:00,  1.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.87it/s]
#                    all        229        248      0.899      0.745      0.851        0.5
#         suspicious-cap        229         92      0.918      0.783      0.911      0.475
#       suspicious-masks        229         60      0.915      0.722      0.826      0.563
#  suspicious-sunglasses        229         96      0.864      0.729      0.815      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25       7.2
00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.72it/s]
#                    all        229        248      0.935      0.868      0.942      0.616
#         suspicious-cap        229         92      0.954      0.902      0.955       0.51
#       suspicious-masks        229         60      0.948      0.833      0.923      0.711
#  suspicious-sunglasses        229         96      0.903       0.87      0.948      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25       7.2G     0.7182     0.4496      1.272         17        800: 100% 294/294 [02:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.64it/s]
#                    all        229        248      0.936      0.908      0.924      0.596
#         suspicious-cap        229         92      0.896       0.94      0.913      0.469
#       suspicious-masks        229         60      0.976       0.85      0.912      0.709
#  suspicious-sunglasses        229         96      0.937      0.935      0.946      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25       7.2G     0.6822     0.4205      1.239         18        800: 100% 294/294 [02:30<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.71it/s]
#                    all        229        248      0.942      0.856      0.912      0.575
#         suspicious-cap        229         92      0.947      0.924       0.95      0.463
#       suspicious-masks        229         60      0.966      0.767      0.879      0.669
#  suspicious-sunglasses        229         96      0.913      0.877      0.906      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25       7.2G     0.6495     0.3937      1.206         16        800: 100% 294/294 [02:34<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.73it/s]
#                    all        229        248      0.903      0.904      0.922      0.594
#         suspicious-cap        229         92      0.916      0.967      0.952      0.484
#       suspicious-masks        229         60       0.89      0.807      0.886       0.69
#  suspicious-sunglasses        229         96      0.904      0.938       0.93      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25       7.2G     0.6167      0.378      1.178         15        800: 100% 294/294 [02:28<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.46it/s]
#                    all        229        248      0.929      0.878      0.916      0.597
#         suspicious-cap        229         92      0.929      0.946      0.951      0.492
#       suspicious-masks        229         60      0.972        0.8      0.883      0.693
#  suspicious-sunglasses        229         96      0.886      0.887      0.914      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25       7.2G     0.5883     0.3508      1.156         16        800: 100% 294/294 [02:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:04<00:00,  1.98it/s]
#                    all        229        248      0.936      0.894      0.932       0.63
#         suspicious-cap        229         92      0.929      0.924      0.931      0.528
#       suspicious-masks        229         60      0.963      0.864      0.931      0.739
#  suspicious-sunglasses        229         96      0.915      0.894      0.935      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25       7.2G     0.5513     0.3263      1.119         22        800: 100% 294/294 [02:37<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.46it/s]
#                    all        229        248      0.927      0.904       0.94      0.637
#         suspicious-cap        229         92      0.924      0.935      0.955      0.535
#       suspicious-masks        229         60      0.964      0.882      0.925      0.747
#  suspicious-sunglasses        229         96      0.894      0.896      0.941       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25       7.2G     0.5227     0.3135        1.1         18        800: 100% 294/294 [02:38<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:05<00:00,  1.51it/s]
#                    all        229        248      0.936      0.922      0.935      0.633
#         suspicious-cap        229         92      0.933      0.957       0.94      0.521
#       suspicious-masks        229         60      0.981      0.883      0.927      0.747
#  suspicious-sunglasses        229         96      0.893      0.927      0.939       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25       7.2G     0.4995     0.2949      1.081         17        800: 100% 294/294 [02:27<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:09<00:00,  1.16s/it]
#                    all        229        248       0.92      0.912      0.935      0.631
#         suspicious-cap        229         92      0.932      0.935       0.93      0.509
#       suspicious-masks        229         60      0.938      0.883      0.928      0.744
#  suspicious-sunglasses        229         96      0.889      0.917      0.948      0.639
#
# 25 epochs completed in 1.444 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:07<00:00,  1.04it/s]
#                    all        229        248      0.927      0.904       0.94      0.637
#         suspicious-cap        229         92      0.924      0.935      0.955      0.534
#       suspicious-masks        229         60      0.964      0.882      0.925      0.747
#  suspicious-sunglasses        229         96      0.895      0.896      0.941       0.63
# Speed: 4.8ms pre-process, 7.0ms inference, 0.0ms loss, 3.3ms post-process per image
# Results saved to runs/detect/train

# %% [markdown]
# ---
# # Model Evaluation
#
#
#
# ---

# %% [markdown]
# After running the model I will now look into the result files that it has produced.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    train_batch2.jpg
# confusion_matrix.png				    train_batch4410.jpg
# events.out.tfevents.1690804319.8f5c82bcc197.1431.0  train_batch4411.jpg
# F1_curve.png					    train_batch4412.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# R_curve.png					    val_batch1_labels.jpg
# results.csv					    val_batch1_pred.jpg
# results.png					    val_batch2_labels.jpg
# train_batch0.jpg				    val_batch2_pred.jpg
# train_batch1.jpg				    weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/F1_curve.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/P_curve.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/PR_curve.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/R_curve.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# 2023-07-31 13:19:07.152255: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/suspicious-objects-articles-3-1/valid/labels.cache... 229 images, 0 backgrounds, 0 corrupt: 100% 229/229 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 76, len(boxes) = 248. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 15/15 [00:10<00:00,  1.45it/s]
#                    all        229        248      0.927      0.904       0.94      0.637
#         suspicious-cap        229         92      0.924      0.935      0.955      0.534
#       suspicious-masks        229         60      0.964      0.882      0.925      0.748
#  suspicious-sunglasses        229         96      0.894      0.896      0.941       0.63
# Speed: 4.1ms pre-process, 15.8ms inference, 0.0ms loss, 4.7ms post-process per image

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# 2023-07-31 13:19:33.180985: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# image 1/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0000_jpg.rf.b2f21d17160bb4729219f94b5439878b.jpg: 800x800 1 suspicious-masks, 25.0ms
# image 2/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0001_jpg.rf.5f1400a633d803feb8e3407d23d5f489.jpg: 800x800 1 suspicious-masks, 24.2ms
# image 3/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0007_jpg.rf.f239f22feebeee997e7cf2b8fcc0e477.jpg: 800x800 1 suspicious-masks, 24.1ms
# image 4/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0009_jpg.rf.31181f113febe404e045c6aeaa6632f1.jpg: 800x800 1 suspicious-masks, 24.1ms
# image 5/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0036_jpg.rf.324936672620abf3dc5a678ce2c46e9d.jpg: 800x800 1 suspicious-masks, 24.1ms
# image 6/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0053_jpg.rf.d42ed4e06feb86d03a4ea11885b160c3.jpg: 800x800 1 suspicious-masks, 24.1ms
# image 7/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0055_jpg.rf.4ffe4bd011241e755702844669269cdf.jpg: 800x800 1 suspicious-masks, 24.1ms
# image 8/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0063_jpg.rf.500fc8bda009b66ca1f2a084eb9d7cb2.jpg: 800x800 1 suspicious-masks, 22.8ms
# image 9/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0085_jpg.rf.775e9c06e0a6675a36ea37011a54c174.jpg: 800x800 1 suspicious-masks, 22.7ms
# image 10/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0101_jpg.rf.3b739951c0084e59b88efa8958bc1c01.jpg: 800x800 2 suspicious-maskss, 22.3ms
# image 11/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0112_jpg.rf.31fe591b3efb231138c348ac0639817c.jpg: 800x800 1 suspicious-masks, 22.5ms
# image 12/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0119_jpg.rf.e63e05f58c7a976ee33c20d7e18f7cc1.jpg: 800x800 1 suspicious-masks, 20.1ms
# image 13/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0129_jpg.rf.19553ce64d206ca174cd5458c5eeb18e.jpg: 800x800 1 suspicious-masks, 20.1ms
# image 14/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0139_jpg.rf.70e2cf0652bbd857a69bed9c27a00d92.jpg: 800x800 1 suspicious-masks, 19.8ms
# image 15/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0177_jpg.rf.1541539299aa0a27c1fea44fa09ca4b5.jpg: 800x800 1 suspicious-masks, 19.8ms
# image 16/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0178_jpg.rf.c2b6dd588d2ad0bb872f7845007f0273.jpg: 800x800 1 suspicious-masks, 19.5ms
# image 17/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0188_jpg.rf.72ea73f067723a83cd5b77ae5f875555.jpg: 800x800 2 suspicious-maskss, 19.5ms
# image 18/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0206_jpg.rf.83e8081c7759d7ac83603f827fa910fb.jpg: 800x800 3 suspicious-maskss, 19.2ms
# image 19/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0251_jpg.rf.07fbdaee40b1054ee8c512a67e284690.jpg: 800x800 3 suspicious-maskss, 19.2ms
# image 20/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0252_jpg.rf.d9cdc2e968d7ac87ed4a6889fcfebe74.jpg: 800x800 4 suspicious-maskss, 19.2ms
# image 21/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0255_jpg.rf.3085ed39f518b611df24608aeceac82f.jpg: 800x800 2 suspicious-maskss, 19.2ms
# image 22/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0267_jpg.rf.1e3c764a821b69e4c827244b92b27cff.jpg: 800x800 1 suspicious-masks, 19.2ms
# image 23/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0278_jpg.rf.db8b4b66a901971cf56b83746cb44910.jpg: 800x800 1 suspicious-masks, 19.2ms
# image 24/190 /content/datasets/suspicious-objects-articles-3-1/test/images/0279_jpg.rf.911eee8cc81da221b62a8ba779c4435d.jpg: 800x800 2 suspicious-maskss, 19.2ms
# image 25/190 /content/datasets/suspicious-objects-articles-3-1/test/images/1-16_jpg.rf.8b266c972529abd752440f092bae846b.jpg: 800x800 1 suspicious-sunglasses, 19.2ms
# image 26/190 /content/datasets/suspicious-objects-articles-3-1/test/images/1563518951300_0-_jpg.rf.0ab355dc8beb97d8cee858b9e805f961.jpg: 800x800 1 suspicious-cap, 19.2ms
# image 27/190 /content/datasets/suspicious-objects-articles-3-1/test/images/P6LOSTBL_jpg.rf.707593dbc7ae2eab8464a3a0b0be8b0d.jpg: 800x800 1 suspicious-cap, 19.2ms
# image 28/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091553447-MP_jpg.rf.68fbc157b5440cabc2dfb7ec65087643.jpg: 800x800 1 suspicious-sunglasses, 19.1ms
# image 29/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091553447-MP_jpg.rf.efc677f26006880b24fca580da62656e.jpg: 800x800 1 suspicious-sunglasses, 16.8ms
# image 30/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091622954-MP_jpg.rf.9ffb8ee07b172e48395b7280899d6ec2.jpg: 800x800 2 suspicious-sunglassess, 16.8ms
# image 31/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091626119-MP_jpg.rf.e9f595c3bde9001f624e37ad0a2d3a19.jpg: 800x800 1 suspicious-sunglasses, 16.8ms
# image 32/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091652679-MP_jpg.rf.d332f55b07c44a8a9e17b25c8ed783ac.jpg: 800x800 1 suspicious-sunglasses, 16.4ms
# image 33/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091711068-MP_jpg.rf.46429e3a9e1be36524521506fe0f8289.jpg: 800x800 1 suspicious-sunglasses, 16.4ms
# image 34/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091712695-MP_jpg.rf.5c5d0e81f405d526448d8af085294628.jpg: 800x800 1 suspicious-sunglasses, 15.8ms
# image 35/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091735111-MP_jpg.rf.96263aba9db8dab213b398cf171a408f.jpg: 800x800 1 suspicious-sunglasses, 14.7ms
# image 36/190 /content/datasets/suspicious-objects-articles-3-1/test/images/PXL_20230505_091741466-MP_jpg.rf.8558e8eaeab151b3e4fa2f859a74a988.jpg: 800x800 1 suspicious-sunglasses, 14.8ms
# image 37/190 /content/datasets/suspicious-objects-articles-3-1/test/images/Priyanka20Chopra_jpg.rf.6b582e6eb5da2c061159d76bedeb461f.jpg: 800x800 1 suspicious-sunglasses, 14.7ms
# image 38/190 /content/datasets/suspicious-objects-articles-3-1/test/images/S5c06289980784015a2faee4e937d40d8H_jpg.rf.60e251aaff2f58f5622805c91d29ec3e.jpg: 800x800 1 suspicious-cap, 1 suspicious-sunglasses, 14.3ms
# image 109/190 /content/datasets/suspicious-objects-articles-3-1/test/images/photo_2023-07-31-18-25-57_jpeg.rf.83faa664117ecf725e85484c7aa3a632.jpg: 800x800 1 suspicious-cap, 1 suspicious-masks, 2 suspicious-sunglassess, 12.3ms
# image 110/190 /content/datasets/suspicious-objects-articles-3-1/test/images/portrait-of-smiling-man-wearing-cap-and-glasses-NGF00462_jpg.rf.bd49bd1a0262e3d023af4c477e1bd857.jpg: 800x800 1 suspicious-cap, 2 suspicious-sunglassess, 12.3ms
# image 111/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses0_jpg.rf.23b7792f38e02901e82cab7f27831142.jpg: 800x800 1 suspicious-sunglasses, 12.1ms
# image 112/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses138_jpg.rf.63576db457289b90456166e273785274.jpg: 800x800 1 suspicious-sunglasses, 12.0ms
# image 113/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses139_jpg.rf.435a37d180df7c0813ae0c97712446ae.jpg: 800x800 1 suspicious-sunglasses, 12.1ms
# image 114/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses143_jpg.rf.c54d5842887463a4983064e9fe05dbe8.jpg: 800x800 1 suspicious-sunglasses, 13.1ms
# image 115/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses208_jpg.rf.056a2e0b88a9e3aae5c1a2f60fec2bfe.jpg: 800x800 1 suspicious-sunglasses, 12.4ms
# image 116/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses227_jpg.rf.747b80c9b3002b68bcd237bdadb39955.jpg: 800x800 1 suspicious-sunglasses, 12.3ms
# image 117/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses250_jpg.rf.0f5ee1c76fc7267bcdd980ef05a01442.jpg: 800x800 1 suspicious-sunglasses, 12.9ms
# image 118/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses253_jpg.rf.2b7997c7241c2ab7222b75cf5ef749e5.jpg: 800x800 1 suspicious-sunglasses, 12.2ms
# image 119/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses25_jpg.rf.783d6886fbff29cb88df9f4bad056fa9.jpg: 800x800 1 suspicious-sunglasses, 12.9ms
# image 120/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses277_jpg.rf.710dce4ff309416632fa8d267c0627b3.jpg: 800x800 1 suspicious-sunglasses, 12.3ms
# image 121/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses27_jpg.rf.bafe483675184c35934c56ae386f8c2d.jpg: 800x800 3 suspicious-sunglassess, 12.4ms
# image 122/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses280_jpg.rf.56b21ce2c0aa741e84a54b283d19e3bb.jpg: 800x800 1 suspicious-sunglasses, 12.3ms
# image 123/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses41_jpg.rf.fbb4d737a4e79b4d2b0589771d577ab5.jpg: 800x800 1 suspicious-sunglasses, 12.2ms
# image 124/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses44_jpg.rf.daf01b82d55968cc7fce713e2e03769f.jpg: 800x800 1 suspicious-sunglasses, 13.2ms
# image 125/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses50_jpg.rf.5cb14e06b0329bc5d5530129dc9d05d3.jpg: 800x800 1 suspicious-sunglasses, 12.3ms
# image 126/190 /content/datasets/suspicious-objects-articles-3-1/test/images/side-view-of-sunglasses70_jpg.rf.2cc6d6715ec3e14dba4bddad3b6da90c.jpg: 800x800 1 suspicious-sunglasses, 12.4ms
# image 127/190 /content/datasets/suspicious-objects-articles-3-1/test/images/sunglasses-top_jpg.rf.f9d925373e0140927d0261e32c660da8.jpg: 800x800 2 suspicious-sunglassess, 12.1ms
# image 128/190 /content/datasets/suspicious-objects-articles-3-1/test/images/sunglasses1_jpg.rf.a72fd7a0931fc72904fbbb6e2dcbd03d.jpg: 800x800 1 suspicious-sunglasses, 12.4ms
# image 129/190 /content/datasets/suspicious-objects-articles-3-1/test/images/sunglasses2_jpg.rf.1a0aa84f5878d63e0a7026aa3ff79d77.jpg: 800x800 1 suspicious-sunglasses, 12.4ms
190 /content/datasets/suspicious-objects-articles-3-1/test/images/with_mask_90_jpg.rf.f75484339132395434de6ee13e16bc9c.jpg: 800x800 1 suspicious-masks, 12.3ms
# image 187/190 /content/datasets/suspicious-objects-articles-3-1/test/images/with_mask_912_jpg.rf.d9961b45dcfcbd22f11f971b2cdb6232.jpg: 800x800 1 suspicious-masks, 12.2ms
# image 188/190 /content/datasets/suspicious-objects-articles-3-1/test/images/with_mask_924_jpg.rf.969822548e74abf7b4398ffe4d8360a4.jpg: 800x800 1 suspicious-masks, 12.5ms
# image 189/190 /content/datasets/suspicious-objects-articles-3-1/test/images/with_mask_929_jpg.rf.7a353087676838f47a15fdc475fc06e9.jpg: 800x800 1 suspicious-masks, 12.2ms
# image 190/190 /content/datasets/suspicious-objects-articles-3-1/test/images/with_mask_9_jpg.rf.79b14c3947da3da1c65401a5684d6e46.jpg: 800x800 1 suspicious-masks, 12.8ms
# Speed: 0.7ms pre-process, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict2/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %% [markdown]
# ## Deploy model on Roboflow and domain https://dmirfan.online
#
# Once model has been trained, I have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of my project. Now, I will upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.134 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.134`
# View the status of your deployment at: https://app.roboflow.com/capstone-mbl6k/suspicious-objects-articles-3/1
# Share your model with the world at: https://universe.roboflow.com/capstone-mbl6k/suspicious-objects-articles-3/model/1

# %% [markdown]
# ---
# # Conclusions And Recommendations
#
#
#
# ---

# %% [markdown]
# Recommendation 1: Implement in Train Cabins and Platforms
#
# The first and most logical place to implement suspicious object detection would be within the train cabins and platforms of the Mass Rapid Transit (MRT) system. These areas see a significant flow of passengers every day, making them potential targets for security threats. By integrating the system within these high-traffic areas, it can help identify and alert the authorities of any suspicious objects in real-time, thus mitigating potential risks.
#
# Recommendation 2: High-Density Public Spaces
#
# High-density public spaces such as shopping centers, parks, and tourist attractions should also be prioritized. These are places where large numbers of people gather, increasing the potential risk. Additionally, due to the sheer number of objects and activities in these areas, manual surveillance can be challenging, making the need for an intelligent detection system even more crucial.
#
# Recommendation 3: Transportation Hubs
#
# Transportation hubs, including bus terminals, MRT interchanges, and airports, should also be considered. These places are not only high traffic but also serve as critical infrastructure. Implementing a suspicious object detection system in these areas can enhance overall security and create a safer environment for both travelers and staff.
#
# In each case, the surveillance cameras should be positioned strategically to cover the maximum area and reduce blind spots. The aim is to ensure a comprehensive view of the surroundings, providing the AI system with the necessary data to identify and track suspicious objects effectively.

# %% [markdown]
# ---
# # Future Works
#
#
#
# ---

# %% [markdown]
# Future Work 1: Increase in Object Diversity Recognition
#
# While the current generation of object detection systems is promising, there's scope for further enhancement, particularly in recognizing a more diverse range of objects. Future systems could be trained to identify not only larger items like luggage or parcels but also smaller or less common objects that could be suspicious. Such advancements would require extensive machine learning training with diverse datasets and continuous updating of the system as new object types are introduced.
#
# Future Work 2: Detecting and Interpreting Body Language
#
# The addition of body language interpretation to object detection systems could significantly improve their efficacy. For instance, detecting unusual or suspicious behavior in individuals carrying or leaving behind objects can be an additional layer of security. Training AI models to analyze body language would involve complex machine learning and require extensive, diverse datasets of human behaviors. Ethical considerations, such as privacy and the risk of bias, would also need to be carefully managed.
#
# Future Work 3: Enhancing Performance in Crowded Spaces
#
# Detecting suspicious objects or activities in crowded spaces is a significant challenge due to the number of objects and individuals present. Future work could focus on improving the systems' ability to function effectively in such environments. Techniques such as crowd segmentation, which involves separating individual members of a crowd for analysis, and multi-object tracking, could be further developed. These advancements will require sophisticated algorithm development and extensive testing to ensure accuracy and reliability.
